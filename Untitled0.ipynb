# %% [markdown]
# <a href="https://colab.research.google.com/github/PRANAV40/C_Programs/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
print(cv2.__version__)
# Out:
# 4.1.2

# %%
# !pip install numpy

# %%
# !wget "https://www.cricketcountry.com/wp-content/uploads/2015/03/Mohammed-Shami-of-India-is-congratulated-by-teammates7.jpg"
# Out:
# --2021-02-10 15:29:08--  https://www.cricketcountry.com/wp-content/uploads/2015/03/Mohammed-Shami-of-India-is-congratulated-by-teammates7.jpg
# Resolving www.cricketcountry.com (www.cricketcountry.com)... 184.30.186.160, 2600:1406:c800:39f::2965, 2600:1406:c800:394::2965
# Connecting to www.cricketcountry.com (www.cricketcountry.com)|184.30.186.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4452638 (4.2M) [image/jpeg]
# Saving to: ‘Mohammed-Shami-of-India-is-congratulated-by-teammates7.jpg’
#
# Mohammed-Shami-of-I 100%[===================>]   4.25M  --.-KB/s    in 0.07s
#
# 2021-02-10 15:29:08 (59.9 MB/s) - ‘Mohammed-Shami-of-India-is-congratulated-by-teammates7.jpg’ saved [4452638/4452638]

# %%
img = cv2.imread('Mohammed-Shami-of-India-is-congratulated-by-teammates7.jpg')

# %%
if img is None:
  print("open error")
else:
  print("image loaded")
# Out:
# image loaded

# %%
#cv2.imshow('Mohammed-Shami-of-India-is-congratulated-by-teammates7', img)

# %%
print(img.shape)
# Out:
# (2000, 3000, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img[:2,:2])
# Out:
# [[[ 52  63  93]
#   [ 56  67  97]]
#
#  [[ 59  70 100]
#   [ 60  71 101]]]

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
for i in range(5):
  for j in range(5):
    img[50+i,235+j] = (0,255,0)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
stump = img[1000:1750,2700:2990]

# %%
plt.imshow(stump)

# %%
men = img[250:1850,250:2800]

# %%
plt.imshow(men)

# %%
# !wget "https://www.cricket.com.au/~/-/media/News/2019/01/15Dhoni.ashx?w=1600"
# Out:
# --2021-02-10 16:26:11--  https://www.cricket.com.au/~/-/media/News/2019/01/15Dhoni.ashx?w=1600
# Resolving www.cricket.com.au (www.cricket.com.au)... 104.69.71.107
# Connecting to www.cricket.com.au (www.cricket.com.au)|104.69.71.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 480015 (469K) [image/jpeg]
# Saving to: ‘15Dhoni.ashx?w=1600’
#
# 15Dhoni.ashx?w=1600 100%[===================>] 468.76K  --.-KB/s    in 0.03s
#
# 2021-02-10 16:26:12 (14.3 MB/s) - ‘15Dhoni.ashx?w=1600’ saved [480015/480015]

# %%
img = cv2.imread('15Dhoni.ashx?w=1600')

# %%
if img is None:
  print("open error")
else:
  print("image loaded")
# Out:
# image loaded

# %%
#cv2.imshow('15Dhoni.ashx?w=1600',img)

# %%
print(img.shape)
# Out:
# (1037, 1600, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img[:2,:2])
# Out:
# [[[108  48   6]
#   [108  50   8]]
#
#  [[105  46   6]
#   [104  46   4]]]

# %%
plt.imshow(img)

# %%
for i in range(5):
  for j in range(5):
    img[50+i,235+j] = (0,255,0)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
stump = img[550:1050,100:400]

# %%
plt.imshow(stump)
